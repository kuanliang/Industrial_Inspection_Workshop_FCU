# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/Data'
# Out:
# bank		     bank.zip  mnist.zip  Task02_Heart	Task09_Spleen
# bank-additional.zip  DAGM      SMART	  Task06_Lung

# %%
import nibabel as nib

# %%
img = nib.load('/content/drive/My Drive/Data/Task02_Heart/imagesTr/la_010.nii.gz')

# %%
img.shape
# Out:
# (320, 320, 120)

# %%
img_data = img.get_data()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.

# %%
img_data.shape
# Out:
# (320, 320, 120)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(img_data[:,:,50], cmap='gray')

# %%
lbl = nib.load('/content/drive/My Drive/Data/Task02_Heart/labelsTr/la_010.nii.gz')

# %%
lbl_data = lbl.get_data()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(lbl_data[:,:,50], cmap='gray')

# %%
fig = plt.figure(figsize=(20,20))
for index in range(30):
    y = fig.add_subplot(5,6,index+1)
    y.imshow(img_data[:,:,index+50], cmap='gray')

# %%
fig = plt.figure(figsize=(20,20))
for index in range(30):
    y = fig.add_subplot(5,6,index+1)
    y.imshow(lbl_data[:,:,index+50], cmap='gray')

# %%
import numpy as np
import ipywidgets as ipyw
import matplotlib.pyplot as plt
# %matplotlib inline

class ImageSliceViewer3D:
    """ 
    ImageSliceViewer3D is for viewing volumetric image slices in jupyter or
    ipython notebooks. 
    
    User can interactively change the slice plane selection for the image and 
    the slice plane being viewed. 

    Argumentss:
    Volume = 3D input image
    figsize = default(8,8), to set the size of the figure
    cmap = default('plasma'), string for the matplotlib colormap. You can find 
    more matplotlib colormaps on the following link:
    https://matplotlib.org/users/colormaps.html
    
    """
    
    def __init__(self, volume, figsize=(8,8), cmap='gray'):
        self.volume = volume
        self.figsize = figsize
        self.cmap = cmap
        self.v = [np.min(volume), np.max(volume)]
        
        # Call to select slice plane
        ipyw.interact(self.view_selection, view=ipyw.RadioButtons(
            options=['x-y','y-z', 'z-x'], value='x-y', 
            description='Slice plane selection:', disabled=False,
            style={'description_width': 'initial'}))
    
    def view_selection(self, view):
        # Transpose the volume to orient according to the slice plane selection
        orient = {"y-z":[1,2,0], "z-x":[2,0,1], "x-y": [0,1,2]}
        self.vol = np.transpose(self.volume, orient[view])
        maxZ = self.vol.shape[2] - 1
        
        # Call to view a slice within the selected slice plane
        ipyw.interact(self.plot_slice, 
            z=ipyw.IntSlider(min=0, max=maxZ, step=1, continuous_update=False, 
            description='Image Slice:'))
        
    def plot_slice(self, z):
        # Plot slice for the given plane and slice
        self.fig = plt.figure(figsize=self.figsize)
        plt.imshow(self.vol[:,:,z], cmap=plt.get_cmap(self.cmap), 
            vmin=self.v[0], vmax=self.v[1])

# %%
from IPython import display
import time
def visual_inspection(img_df, time_sleep=0.1):
    for i in range(len(img_df[0,0,:])):
        plt.figure(figsize=(10, 10))
        plt.imshow(img_df[:,:,i], cmap='gray')
        #plt.title()
        display.clear_output(wait=True)
        plt.show()
        time.sleep(time_sleep)

# %%
visual_inspection(img_data)

# %%
visual_inspection(lbl_data)

# %%
import glob
import os

# %%
import imageio
path_to_temp = '/content/drive/My Drive/Data/temp/'
def create_gif(img_df, duration, output):
    images = []
    for i in range(len(img_df[0,0,:])):
        plt.imsave(path_to_temp + str(i) + '.jpg', img_df[:,:,i], cmap='gray')
        images.append(imageio.imread(path_to_temp + str(i) + '.jpg'))
        
    filename = path_to_temp + output + '.gif'
    imageio.mimsave(filename, images, duration=duration)
    for jpg_file in glob.glob(path_to_temp + '*.jpg'):
        os.remove(jpg_file)

# %%
# !mkdir temp

# %%
create_gif(img_data, duration=0.5, output='test')

# %%
img_data.shape
# Out:
# (320, 320, 120)

# %%
def collect_imgs_masks(img, lbl):
    img_X = np.ndarray((120, 320, 320, 1))
    mask_y = np.ndarray((120, 320, 320, 1))
    for index in range(120):
        img_X[index,:,:,0] = img[:,:,index]
        mask_y[index,:,:,0] = lbl[:,:,index]
    return img_X, mask_y

# %%
img_X, mask_y = collect_imgs_masks(img_data, lbl_data)

# %%
plt.imshow(img_X[0,:,:,0], cmap='gray')

# %%
import cv2
def inspect_img_mask(image, mask):
    '''
    '''
    # scale pred and mask's pixel range to 0~255
    mask = np.array(255*mask, dtype=np.uint8)    
    # transform both of them to rgb
    rgb_mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2RGB)
    rgb_mask[:,:,1:3] = 0*rgb_mask[:,:,1:2]
    #img_mask = cv2.addWeighted(image, 1, rgb_mask, 0.5, 1)    
    
    
    plt.figure(figsize=(20, 20))  
    plt.subplot(1,3,1)
    plt.imshow(image, cmap='gray')
    plt.title('Original image')
    plt.axis('off')
    plt.subplot(1,3,2)
    plt.imshow(mask, cmap='gray')
    plt.title('Mask')
    plt.axis('off')
    #plt.subplot(1,3,3)
    #plt.imshow(img_mask)
    #plt.title('Mask on image')
    #plt.axis('off')

# %%
index = 50
inspect_img_mask(img_X[index,:,:,0], mask_y[index,:,:,0])

# %%
from sklearn.model_selection import train_test_split
img_X = img_X / 255.
X_train, X_test, y_train, y_test = train_test_split(img_X, mask_y, test_size=0.2, random_state=12)

# %%
from keras.models import Model
from keras.layers import Input, merge, Conv2D, MaxPooling2D, UpSampling2D,Lambda, Conv2DTranspose, concatenate, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K
from scipy.ndimage.measurements import label
import time

# %%
img_rows = 320
img_cols = 320

# %%
### Defining a small Unet
### Smaller Unet defined so it fits in memory

def get_small_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(8, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(8, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(16, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(64, kernel_size=(2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(64, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(32, kernel_size=(2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(32, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(16, kernel_size=(2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(16, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(8, kernel_size=(2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(8, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(8, (3, 3), activation='relu', padding='same')(conv9)
    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)
    model = Model(inputs=inputs, outputs=conv10)

    
    return model

# %%
model = get_small_unet()

# %%
### IOU or dice coeff calculation
def IOU_calc(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    
    return 2*(intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def IOU_calc_loss(y_true, y_pred):
    return -IOU_calc(y_true, y_pred)

# %%
smooth = 1.
model.compile(optimizer=Adam(lr=1e-4), loss=IOU_calc_loss, metrics=[IOU_calc])

# %%
history = model.fit(img_X, mask_y, batch_size=10, epochs=100, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
#  2/10 [=====>........................] - ETA: 0s - loss: -0.0065 - IOU_calc: 0.0065WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0157s vs `on_train_batch_end` time: 0.0490s). Check your callbacks.
# 10/10 [==============================] - ETA: 0s - loss: -0.0097 - IOU_calc: 0.0099WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0044s vs `on_test_batch_end` time: 0.0101s). Check your callbacks.
# 10/10 [==============================] - 2s 164ms/step - loss: -0.0097 - IOU_calc: 0.0099 - val_loss: -1.8917e-04 - val_IOU_calc: 1.5319e-04
# Epoch 2/100
# 10/10 [==============================] - 1s 68ms/step - loss: -0.0102 - IOU_calc: 0.0099 - val_loss: -1.9780e-04 - val_IOU_calc: 1.6007e-04
# Epoch 3/100
# 10/10 [==============================] - 1s 68ms/step - loss: -0.0107 - IOU_calc: 0.0105 - val_loss: -2.0599e-04 - val_IOU_calc: 1.6661e-04
# Epoch 4/100
# 10/10 [==============================] - 1s 68ms/step - loss: -0.0112 - IOU_calc: 0.0108 - val_loss: -2.1399e-04 - val_IOU_calc: 1.7299e-04
# Epoch 5/100
# 10/10 [==============================] - 1s 68ms/step - loss: -0.0116 - IOU_calc: 0.0115 - val_loss: -2.2075e-04 - val_IOU_calc: 1.7836e-04
# Epoch 6/100
# 10/10 [==============================] - 1s 69ms/step - loss: -0.0119 - IOU_calc: 0.0114 - val_loss: -2.2530e-04 - val_IOU_calc: 1.8197e-04
# Epoch 7/100
# 10/10 [==============================] - 1s 68ms/step - loss: -0.0121 - IOU_calc: 0.0118 - val_loss: -2.2752e-04 - val_IOU_calc: 1.8373e-04
# Epoch 8/100
# 10/10 [==============================] - 1s 69ms/step - loss: -0.0122 - IOU_calc: 0.0122 - val_loss: -2.2941e-04 - val_IOU_calc: 1.8526e-04
# Epoch 9/100
# 10/10 [==============================] - 1s 68ms/step - loss: -0.0123 - IOU_calc: 0.0124 - val_loss: -2.3142e-04 - val_IOU_calc: 1.8688e-04
# Epoch 10/100
# 10/10 [==============================] - 1s 69ms/step - loss: -0.0124 - IOU_calc: 0.0123 - val_loss: -2.3390e-04 - val_IOU_calc: 1.8888e-04
# Epoch 11/100
# 10/10 [==============================] - 1s 69ms/step - loss: -0.0126 - IOU_calc: 0.0126 - val_loss: -2.3775e-04 - val_IOU_calc: 1.9199e-04
# Epoch 12/100
# 10/10 [==============================] - 1s 69ms/step - loss: -0.0129 - IOU_calc: 0.0131 - val_loss: -2.4466e-04 - val_IOU_calc: 1.9757e-04
# Epoch 13/100
# 10/10 [==============================] - 1s 68ms/step - loss: -0.0137 - IOU_calc: 0.0136 - val_loss: -2.5803e-04 - val_IOU_calc: 2.0840e-04
# Epoch 14/100
# 10/10 [==============================] - 1s 68ms/step - loss: -0.0153 - IOU_calc: 0.0155 - val_loss: -2.7879e-04 - val_IOU_calc: 2.2528e-04
# Epoch 15/100
# 10/10 [==============================] - 1s 66ms/step - loss: -0.0197 - IOU_calc: 0.0193 - val_loss: -3.2881e-04 - val_IOU_calc: 2.6658e-04
# Epoch 16/100
# 10/10 [==============================] - 1s 69ms/step - loss: -0.0298 - IOU_calc: 0.0296 - val_loss: -4.8070e-04 - val_IOU_calc: 3.8847e-04
# Epoch 17/100
# 10/10 [==============================] - 1s 69ms/step - loss: -0.0941 - IOU_calc: 0.1010 - val_loss: -5.4477e-04 - val_IOU_calc: 6.5094e-04
# Epoch 18/100
# 10/10 [==============================] - 1s 68ms/step - loss: -3.7785e-04 - IOU_calc: 3.8278e-04 - val_loss: -0.0043 - val_IOU_calc: 0.0052
# Epoch 19/100
# 10/10 [==============================] - 1s 67ms/step - loss: -5.2514e-04 - IOU_calc: 5.4098e-04 - val_loss: -0.0121 - val_IOU_calc: 0.0152
# Epoch 20/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.7874e-04 - IOU_calc: 6.0249e-04 - val_loss: -0.0195 - val_IOU_calc: 0.0251
# Epoch 21/100
# 10/10 [==============================] - 1s 67ms/step - loss: -6.0846e-04 - IOU_calc: 6.0766e-04 - val_loss: -0.0234 - val_IOU_calc: 0.0304
# Epoch 22/100
# 10/10 [==============================] - 1s 67ms/step - loss: -5.5987e-04 - IOU_calc: 5.5354e-04 - val_loss: -0.0253 - val_IOU_calc: 0.0329
# Epoch 23/100
# 10/10 [==============================] - 1s 67ms/step - loss: -5.4063e-04 - IOU_calc: 5.4769e-04 - val_loss: -0.0261 - val_IOU_calc: 0.0340
# Epoch 24/100
# 10/10 [==============================] - 1s 67ms/step - loss: -5.7788e-04 - IOU_calc: 5.9684e-04 - val_loss: -0.0267 - val_IOU_calc: 0.0347
# Epoch 25/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.6344e-04 - IOU_calc: 5.8448e-04 - val_loss: -0.0271 - val_IOU_calc: 0.0353
# Epoch 26/100
# 10/10 [==============================] - 1s 68ms/step - loss: -6.4064e-04 - IOU_calc: 6.3346e-04 - val_loss: -0.0276 - val_IOU_calc: 0.0360
# Epoch 27/100
# 10/10 [==============================] - 1s 67ms/step - loss: -6.0901e-04 - IOU_calc: 6.2080e-04 - val_loss: -0.0279 - val_IOU_calc: 0.0365
# Epoch 28/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.8244e-04 - IOU_calc: 5.9281e-04 - val_loss: -0.0283 - val_IOU_calc: 0.0371
# Epoch 29/100
# 10/10 [==============================] - 1s 67ms/step - loss: -5.8601e-04 - IOU_calc: 6.2191e-04 - val_loss: -0.0287 - val_IOU_calc: 0.0376
# Epoch 30/100
# 10/10 [==============================] - 1s 68ms/step - loss: -6.0585e-04 - IOU_calc: 6.0366e-04 - val_loss: -0.0291 - val_IOU_calc: 0.0381
# Epoch 31/100
# 10/10 [==============================] - 1s 64ms/step - loss: -5.6409e-04 - IOU_calc: 5.8000e-04 - val_loss: -0.0294 - val_IOU_calc: 0.0386
# Epoch 32/100
# 10/10 [==============================] - 1s 67ms/step - loss: -5.9379e-04 - IOU_calc: 6.0874e-04 - val_loss: -0.0298 - val_IOU_calc: 0.0390
# Epoch 33/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.8698e-04 - IOU_calc: 5.8887e-04 - val_loss: -0.0301 - val_IOU_calc: 0.0395
# Epoch 34/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.9196e-04 - IOU_calc: 6.0965e-04 - val_loss: -0.0304 - val_IOU_calc: 0.0400
# Epoch 35/100
# 10/10 [==============================] - 1s 69ms/step - loss: -5.4764e-04 - IOU_calc: 5.4844e-04 - val_loss: -0.0307 - val_IOU_calc: 0.0404
# Epoch 36/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.9923e-04 - IOU_calc: 6.0525e-04 - val_loss: -0.0310 - val_IOU_calc: 0.0408
# Epoch 37/100
# 10/10 [==============================] - 1s 69ms/step - loss: -6.2704e-04 - IOU_calc: 6.3679e-04 - val_loss: -0.0313 - val_IOU_calc: 0.0412
# Epoch 38/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.6653e-04 - IOU_calc: 5.8832e-04 - val_loss: -0.0316 - val_IOU_calc: 0.0416
# Epoch 39/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.5891e-04 - IOU_calc: 5.5936e-04 - val_loss: -0.0319 - val_IOU_calc: 0.0420
# Epoch 40/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.7969e-04 - IOU_calc: 5.8237e-04 - val_loss: -0.0322 - val_IOU_calc: 0.0424
# Epoch 41/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.4155e-04 - IOU_calc: 5.4696e-04 - val_loss: -0.0325 - val_IOU_calc: 0.0427
# Epoch 42/100
# 10/10 [==============================] - 1s 64ms/step - loss: -5.7656e-04 - IOU_calc: 6.0630e-04 - val_loss: -0.0327 - val_IOU_calc: 0.0431
# Epoch 43/100
# 10/10 [==============================] - 1s 69ms/step - loss: -6.0216e-04 - IOU_calc: 6.0294e-04 - val_loss: -0.0330 - val_IOU_calc: 0.0435
# Epoch 44/100
# 10/10 [==============================] - 1s 69ms/step - loss: -5.4513e-04 - IOU_calc: 5.5096e-04 - val_loss: -0.0332 - val_IOU_calc: 0.0439
# Epoch 45/100
# 10/10 [==============================] - 1s 69ms/step - loss: -6.3895e-04 - IOU_calc: 6.5517e-04 - val_loss: -0.0336 - val_IOU_calc: 0.0443
# Epoch 46/100
# 10/10 [==============================] - 1s 69ms/step - loss: -5.9051e-04 - IOU_calc: 6.2857e-04 - val_loss: -0.0338 - val_IOU_calc: 0.0447
# Epoch 47/100
# 10/10 [==============================] - 1s 69ms/step - loss: -6.1336e-04 - IOU_calc: 6.6190e-04 - val_loss: -0.0341 - val_IOU_calc: 0.0451
# Epoch 48/100
# 10/10 [==============================] - 1s 69ms/step - loss: -6.0299e-04 - IOU_calc: 6.3358e-04 - val_loss: -0.0345 - val_IOU_calc: 0.0455
# Epoch 49/100
# 10/10 [==============================] - 1s 69ms/step - loss: -6.8561e-04 - IOU_calc: 7.8175e-04 - val_loss: -0.0348 - val_IOU_calc: 0.0460
# Epoch 50/100
# 10/10 [==============================] - 1s 69ms/step - loss: -5.6280e-04 - IOU_calc: 5.7730e-04 - val_loss: -0.0353 - val_IOU_calc: 0.0467
# Epoch 51/100
# 10/10 [==============================] - 1s 69ms/step - loss: -5.7386e-04 - IOU_calc: 5.7554e-04 - val_loss: -0.0356 - val_IOU_calc: 0.0472
# Epoch 52/100
# 10/10 [==============================] - 1s 70ms/step - loss: -5.7019e-04 - IOU_calc: 5.7030e-04 - val_loss: -0.0359 - val_IOU_calc: 0.0476
# Epoch 53/100
# 10/10 [==============================] - 1s 69ms/step - loss: -5.9717e-04 - IOU_calc: 6.0128e-04 - val_loss: -0.0363 - val_IOU_calc: 0.0480
# Epoch 54/100
# 10/10 [==============================] - 1s 66ms/step - loss: -6.2476e-04 - IOU_calc: 6.7857e-04 - val_loss: -0.0366 - val_IOU_calc: 0.0485
# Epoch 55/100
# 10/10 [==============================] - 1s 70ms/step - loss: -6.7828e-04 - IOU_calc: 6.8399e-04 - val_loss: -0.0370 - val_IOU_calc: 0.0491
# Epoch 56/100
# 10/10 [==============================] - 1s 70ms/step - loss: -5.7582e-04 - IOU_calc: 5.7720e-04 - val_loss: -0.0375 - val_IOU_calc: 0.0497
# Epoch 57/100
# 10/10 [==============================] - 1s 69ms/step - loss: -6.7110e-04 - IOU_calc: 6.6062e-04 - val_loss: -0.0379 - val_IOU_calc: 0.0503
# Epoch 58/100
# 10/10 [==============================] - 1s 69ms/step - loss: -5.6274e-04 - IOU_calc: 5.8692e-04 - val_loss: -0.0383 - val_IOU_calc: 0.0508
# Epoch 59/100
# 10/10 [==============================] - 1s 70ms/step - loss: -5.6340e-04 - IOU_calc: 5.7189e-04 - val_loss: -0.0386 - val_IOU_calc: 0.0513
# Epoch 60/100
# 10/10 [==============================] - 1s 69ms/step - loss: -5.9770e-04 - IOU_calc: 5.9476e-04 - val_loss: -0.0390 - val_IOU_calc: 0.0518
# Epoch 61/100
# 10/10 [==============================] - 1s 70ms/step - loss: -5.6563e-04 - IOU_calc: 5.6730e-04 - val_loss: -0.0394 - val_IOU_calc: 0.0523
# Epoch 62/100
# 10/10 [==============================] - 1s 70ms/step - loss: -6.7984e-04 - IOU_calc: 7.8958e-04 - val_loss: -0.0398 - val_IOU_calc: 0.0528
# Epoch 63/100
# 10/10 [==============================] - 1s 70ms/step - loss: -5.7058e-04 - IOU_calc: 5.6914e-04 - val_loss: -0.0405 - val_IOU_calc: 0.0538
# Epoch 64/100
# 10/10 [==============================] - 1s 70ms/step - loss: -5.7312e-04 - IOU_calc: 5.7615e-04 - val_loss: -0.0410 - val_IOU_calc: 0.0545
# Epoch 65/100
# 10/10 [==============================] - 1s 70ms/step - loss: -6.0290e-04 - IOU_calc: 6.4948e-04 - val_loss: -0.0414 - val_IOU_calc: 0.0551
# Epoch 66/100
# 10/10 [==============================] - 1s 70ms/step - loss: -5.9268e-04 - IOU_calc: 6.0200e-04 - val_loss: -0.0419 - val_IOU_calc: 0.0558
# Epoch 67/100
# 10/10 [==============================] - 1s 71ms/step - loss: -7.1355e-04 - IOU_calc: 7.8585e-04 - val_loss: -0.0425 - val_IOU_calc: 0.0566
# Epoch 68/100
# 10/10 [==============================] - 1s 70ms/step - loss: -6.0729e-04 - IOU_calc: 6.4090e-04 - val_loss: -0.0432 - val_IOU_calc: 0.0576
# Epoch 69/100
# 10/10 [==============================] - 1s 71ms/step - loss: -6.0278e-04 - IOU_calc: 6.2529e-04 - val_loss: -0.0438 - val_IOU_calc: 0.0585
# Epoch 70/100
# 10/10 [==============================] - 1s 71ms/step - loss: -5.3606e-04 - IOU_calc: 5.4885e-04 - val_loss: -0.0444 - val_IOU_calc: 0.0592
# Epoch 71/100
# 10/10 [==============================] - 1s 70ms/step - loss: -6.2350e-04 - IOU_calc: 6.3615e-04 - val_loss: -0.0450 - val_IOU_calc: 0.0600
# Epoch 72/100
# 10/10 [==============================] - 1s 71ms/step - loss: -5.8069e-04 - IOU_calc: 6.1339e-04 - val_loss: -0.0455 - val_IOU_calc: 0.0607
# Epoch 73/100
# 10/10 [==============================] - 1s 71ms/step - loss: -5.8740e-04 - IOU_calc: 6.0621e-04 - val_loss: -0.0461 - val_IOU_calc: 0.0615
# Epoch 74/100
# 10/10 [==============================] - 1s 71ms/step - loss: -5.6840e-04 - IOU_calc: 5.7239e-04 - val_loss: -0.0466 - val_IOU_calc: 0.0623
# Epoch 75/100
# 10/10 [==============================] - 1s 71ms/step - loss: -6.4993e-04 - IOU_calc: 6.6737e-04 - val_loss: -0.0473 - val_IOU_calc: 0.0633
# Epoch 76/100
# 10/10 [==============================] - 1s 66ms/step - loss: -6.0244e-04 - IOU_calc: 6.3690e-04 - val_loss: -0.0480 - val_IOU_calc: 0.0641
# Epoch 77/100
# 10/10 [==============================] - 1s 72ms/step - loss: -5.9920e-04 - IOU_calc: 6.0751e-04 - val_loss: -0.0487 - val_IOU_calc: 0.0651
# Epoch 78/100
# 10/10 [==============================] - 1s 72ms/step - loss: -5.7071e-04 - IOU_calc: 5.7401e-04 - val_loss: -0.0494 - val_IOU_calc: 0.0661
# Epoch 79/100
# 10/10 [==============================] - 1s 71ms/step - loss: -5.7637e-04 - IOU_calc: 6.0368e-04 - val_loss: -0.0501 - val_IOU_calc: 0.0670
# Epoch 80/100
# 10/10 [==============================] - 1s 71ms/step - loss: -6.1179e-04 - IOU_calc: 6.2220e-04 - val_loss: -0.0508 - val_IOU_calc: 0.0680
# Epoch 81/100
# 10/10 [==============================] - 1s 71ms/step - loss: -5.8787e-04 - IOU_calc: 5.8598e-04 - val_loss: -0.0516 - val_IOU_calc: 0.0691
# Epoch 82/100
# 10/10 [==============================] - 1s 68ms/step - loss: -5.7793e-04 - IOU_calc: 5.7520e-04 - val_loss: -0.0523 - val_IOU_calc: 0.0701
# Epoch 83/100
# 10/10 [==============================] - 1s 71ms/step - loss: -6.6148e-04 - IOU_calc: 7.3597e-04 - val_loss: -0.0531 - val_IOU_calc: 0.0712
# Epoch 84/100
# 10/10 [==============================] - 1s 72ms/step - loss: -6.8214e-04 - IOU_calc: 6.9466e-04 - val_loss: -0.0546 - val_IOU_calc: 0.0732
# Epoch 85/100
# 10/10 [==============================] - 1s 72ms/step - loss: -6.7739e-04 - IOU_calc: 6.7319e-04 - val_loss: -0.0558 - val_IOU_calc: 0.0748
# Epoch 86/100
# 10/10 [==============================] - 1s 72ms/step - loss: -5.5942e-04 - IOU_calc: 5.6922e-04 - val_loss: -0.0568 - val_IOU_calc: 0.0763
# Epoch 87/100
# 10/10 [==============================] - 1s 71ms/step - loss: -6.3287e-04 - IOU_calc: 6.3199e-04 - val_loss: -0.0578 - val_IOU_calc: 0.0776
# Epoch 88/100
# 10/10 [==============================] - 1s 73ms/step - loss: -6.8195e-04 - IOU_calc: 6.9223e-04 - val_loss: -0.0591 - val_IOU_calc: 0.0794
# Epoch 89/100
# 10/10 [==============================] - 1s 72ms/step - loss: -5.4767e-04 - IOU_calc: 5.5105e-04 - val_loss: -0.0602 - val_IOU_calc: 0.0808
# Epoch 90/100
# 10/10 [==============================] - 1s 72ms/step - loss: -5.9647e-04 - IOU_calc: 6.4188e-04 - val_loss: -0.0610 - val_IOU_calc: 0.0820
# Epoch 91/100
# 10/10 [==============================] - 1s 72ms/step - loss: -5.8104e-04 - IOU_calc: 5.7950e-04 - val_loss: -0.0621 - val_IOU_calc: 0.0834
# Epoch 92/100
# 10/10 [==============================] - 1s 72ms/step - loss: -5.7315e-04 - IOU_calc: 5.8596e-04 - val_loss: -0.0630 - val_IOU_calc: 0.0846
# Epoch 93/100
# 10/10 [==============================] - 1s 72ms/step - loss: -0.0014 - IOU_calc: 0.0013 - val_loss: -0.0686 - val_IOU_calc: 0.0923
# Epoch 94/100
# 10/10 [==============================] - 1s 72ms/step - loss: -5.7911e-04 - IOU_calc: 5.8646e-04 - val_loss: -0.0717 - val_IOU_calc: 0.0965
# Epoch 95/100
# 10/10 [==============================] - 1s 72ms/step - loss: -6.8995e-04 - IOU_calc: 7.5699e-04 - val_loss: -0.0732 - val_IOU_calc: 0.0985
# Epoch 96/100
# 10/10 [==============================] - 1s 73ms/step - loss: -5.4481e-04 - IOU_calc: 5.5334e-04 - val_loss: -0.0742 - val_IOU_calc: 0.0999
# Epoch 97/100
# 10/10 [==============================] - 1s 73ms/step - loss: -5.8284e-04 - IOU_calc: 6.1045e-04 - val_loss: -0.0748 - val_IOU_calc: 0.1007
# Epoch 98/100
# 10/10 [==============================] - 1s 72ms/step - loss: -6.2157e-04 - IOU_calc: 6.5687e-04 - val_loss: -0.0753 - val_IOU_calc: 0.1014
# Epoch 99/100
# 10/10 [==============================] - 1s 73ms/step - loss: -6.5683e-04 - IOU_calc: 6.4959e-04 - val_loss: -0.0759 - val_IOU_calc: 0.1022
# Epoch 100/100
# 10/10 [==============================] - 1s 73ms/step - loss: -5.5312e-04 - IOU_calc: 5.7295e-04 - val_loss: -0.0764 - val_IOU_calc: 0.1029

# %%
plt.figure(figsize=(20, 5))
plt.plot(model.history.history['loss'], label='Train loss')
plt.plot(model.history.history['val_loss'], label='Val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
predict = model.predict(X_test)

# %%
plt.imshow(predict[10,:,:,0], cmap='gray')

# %%
plt.imshow(y_test[10,:,:,0], cmap='gray')
